# %%
import pandas as pd
import numpy as np

# %%
data = {
'Department': ['IT', 'HR', 'IT', 'Finance', 'HR', 'Finance', 'IT'],
'Employee': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
'Salary': [50000, 40000, 55000, 60000, 42000, 65000, 58000],
'Experience': [2, 1, 3, 5, 2, 6, 4]
}


df = pd.DataFrame(data)
df
# Out:
#   Department Employee  Salary  Experience
# 0         IT        A   50000           2
# 1         HR        B   40000           1
# 2         IT        C   55000           3
# 3    Finance        D   60000           5
# 4         HR        E   42000           2
# 5    Finance        F   65000           6
# 6         IT        G   58000           4

# %% [markdown]
# 3. What is GroupBy?
#
# groupby() is used to split data into groups, apply a function, and combine results.
#
# Split → Apply → Combine

# %% [markdown]
# Basic GroupBy (Single Column)
# Group by Department

# %%
df.groupby('Department')

# %%
df.groupby('Department')['Salary'].mean()
#Calculate Mean Salary per Department
# Out:
# Department
# Finance    62500.000000
# HR         41000.000000
# IT         54333.333333
# Name: Salary, dtype: float64

# %%
# Multiple Aggregations
df.groupby('Department')['Salary'].agg(['mean', 'max', 'min', 'sum'])
# Out:
#                     mean    max    min     sum
# Department
# Finance     62500.000000  65000  60000  125000
# HR          41000.000000  42000  40000   82000
# IT          54333.333333  58000  50000  163000

# %%
# GroupBy with Multiple Columns
df.groupby(['Department', 'Experience'])['Salary'].mean()
# Out:
# Department  Experience
# Finance     5             60000.0
#             6             65000.0
# HR          1             40000.0
#             2             42000.0
# IT          2             50000.0
#             3             55000.0
#             4             58000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Department')['Employee'].count()
#Using GroupBy with Count
# Out:
# Department
# Finance    2
# HR         2
# IT         3
# Name: Employee, dtype: int64

# %%
def salary_range(x):
 return x.max() - x.min()


df.groupby('Department')['Salary'].apply(salary_range)
# Out:
# Department
# Finance    5000
# HR         2000
# IT         8000
# Name: Salary, dtype: int64

# %%
# titanic datasets

# %%
import pandas as pd

df = pd.read_csv("/content/titanic_dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Average Fare per Passenger Class
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: Fare, dtype: float64

# %%
df.groupby('Sex')['Survived'].mean()
#Survival Rate by Gender
# Out:
# Sex
# female    0.82618
# male      0.12930
# Name: Survived, dtype: float64

# %%
# Multiple Aggregations
df.groupby('Pclass')['Fare'].agg(['mean', 'max', 'min', 'count'])
# Out:
#              mean       max  min  count
# Pclass
# 1       87.508992  512.3292  0.0    323
# 2       21.179196   73.5000  0.0    277
# 3       13.302889   69.5500  0.0    708

# %%
#GroupBy Multiple Columns
df.groupby(['Pclass', 'Sex'])['Survived'].mean()
# Out:
# Pclass  Sex
# 1       female    0.979167
#         male      0.251397
# 2       female    0.943396
#         male      0.099415
# 3       female    0.666667
#         male      0.095335
# Name: Survived, dtype: float64

# %%
# Average age of survivors vs non-survivors
df.groupby('Survived')['Age'].mean()
# Out:
# Survived
# 0    30.510986
# 1    28.931079
# Name: Age, dtype: float64

# %%
# Count of male and female passengers per class
df.groupby(['Pclass', 'Sex']).size()
# Out:
# Pclass  Sex
# 1       female    144
#         male      179
# 2       female    106
#         male      171
# 3       female    216
#         male      493
# dtype: int64

# %%
df["average age "]=df.groupby("Sex")["Age"].mean()

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Which embark town has highest survival rate?

df.groupby("Embarked")["Age"].mean()
# Out:
# Embarked
# C    32.332170
# Q    28.630000
# S    29.245205
# Name: Age, dtype: float64

# %% [markdown]
# Now your task is to make a 25 question from chatgpt and practcie your self furst write the question and then answer

# %% [markdown]
# 1. What is groupby() in Pandas?
#
# Answer:
# groupby() is used to divide data into groups and perform calculations on each group.

# %%
import pandas as pd

data = {
    'Student_ID': [101, 102, 103, 104, 105, 106],
    'Name': ['pratik', 'gaurav', 'Haya', 'Gauri', 'Asha', 'Bikash'],
    'Age': [20, 21, 19, 22, 20, 21],
    'Department': ['IT', 'BCA', 'BIM', 'IT', 'BCA', 'BIM'],
    'Marks': [85, 90, 78, 92, 88, 75],
    'City': ['Kathmandu', 'Pokhara', 'Lalitpur', 'Bhaktapur', 'Chitwan', 'Butwal']
}

df = pd.DataFrame(data)

df
# Out:
#    Student_ID    Name  Age Department  Marks       City
# 0         101  pratik   20         IT     85  Kathmandu
# 1         102  gaurav   21        BCA     90    Pokhara
# 2         103    Haya   19        BIM     78   Lalitpur
# 3         104   Gauri   22         IT     92  Bhaktapur
# 4         105    Asha   20        BCA     88    Chitwan
# 5         106  Bikash   21        BIM     75     Butwal

# %%
#1. Display the first 5 rows of the DataFrame.
df.head()
# Out:
#    Student_ID    Name  Age Department  Marks       City
# 0         101  pratik   20         IT     85  Kathmandu
# 1         102  gaurav   21        BCA     90    Pokhara
# 2         103    Haya   19        BIM     78   Lalitpur
# 3         104   Gauri   22         IT     92  Bhaktapur
# 4         105    Asha   20        BCA     88    Chitwan

# %%
#2. Display all column names.
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Department', 'Marks', 'City'], dtype='object')

# %%
#3. Find the total number of students.
df['Name'].count()
# Out:
# np.int64(6)

# %%
#4. Find the average marks of all students.
df['Marks'].mean()
# Out:
# np.float64(84.66666666666667)

# %%
#5. Find the highest marks.
df['Marks'].max()
# Out:
# 92

# %%
#6. Find the lowest marks.
df['Marks'].min()
# Out:
# 75

# %%
#7. Group students by Department.
df.groupby('Department')

# %%
#8. Find the average marks of each Department.
df.groupby('Department')['Marks'].mean()
# Out:
# Department
# BCA    89.0
# BIM    76.5
# IT     88.5
# Name: Marks, dtype: float64

# %%
#9. Find the highest marks in each Department.
df.groupby('Department')['Marks'].max()
# Out:
# Department
# BCA    90
# BIM    78
# IT     92
# Name: Marks, dtype: int64

# %%
#10. Find the lowest marks in each Department.
df.groupby('Department')['Marks'].min()
# Out:
# Department
# BCA    88
# BIM    75
# IT     85
# Name: Marks, dtype: int64

# %%
#11. Find the total marks of each Department.
df.groupby('Department')['Marks'].sum()
# Out:
# Department
# BCA    178
# BIM    153
# IT     177
# Name: Marks, dtype: int64

# %%
#12. Count students in each Department.
df.groupby('Department')['Name'].count()
# Out:
# Department
# BCA    2
# BIM    2
# IT     2
# Name: Name, dtype: int64

# %%
#13. Find the average age of students in each Department.
df.groupby('Department')['Age'].mean()
# Out:
# Department
# BCA    20.5
# BIM    20.0
# IT     21.0
# Name: Age, dtype: float64

# %%
#14. Find the average marks of students from each City.
df.groupby('City')['Marks'].mean()
# Out:
# City
# Bhaktapur    92.0
# Butwal       75.0
# Chitwan      88.0
# Kathmandu    85.0
# Lalitpur     78.0
# Pokhara      90.0
# Name: Marks, dtype: float64

# %%
#15. Find the highest marks from each City.
df.groupby('City')['Marks'].max()
# Out:
# City
# Bhaktapur    92
# Butwal       75
# Chitwan      88
# Kathmandu    85
# Lalitpur     78
# Pokhara      90
# Name: Marks, dtype: int64

# %%
#16. Find the minimum age in each Department.
df.groupby('Department')['Age'].min()
# Out:
# Department
# BCA    20
# BIM    19
# IT     20
# Name: Age, dtype: int64

# %%
#17. Find the maximum age in each Department.
df.groupby('Department')['Age'].max()
# Out:
# Department
# BCA    21
# BIM    21
# IT     22
# Name: Age, dtype: int64

# %%
#18. Find average Marks and average Age for each Department.
df.groupby('Department')[['Marks', 'Age']].mean()
# Out:
#             Marks   Age
# Department
# BCA          89.0  20.5
# BIM          76.5  20.0
# IT           88.5  21.0

# %%
#19. Find maximum Marks and maximum Age for each Department.
df.groupby('Department')[['Marks', 'Age']].max()
# Out:
#             Marks  Age
# Department
# BCA            90   21
# BIM            78   21
# IT             92   22

# %%
#20. Find minimum Marks and minimum Age for each Department.
df.groupby('Department')[['Marks', 'Age']].min()
# Out:
#             Marks  Age
# Department
# BCA            88   20
# BIM            75   19
# IT             85   20

# %%
#21. Find multiple calculations for Marks in each Department.
df.groupby('Department')['Marks'].agg(
    ['mean', 'max', 'min', 'sum', 'count']
)
# Out:
#             mean  max  min  sum  count
# Department
# BCA         89.0   90   88  178      2
# BIM         76.5   78   75  153      2
# IT          88.5   92   85  177      2

# %%
#22. Group students by Department and City.
df.groupby(['Department', 'City'])['Marks'].mean()
# Out:
# Department  City
# BCA         Chitwan      88.0
#             Pokhara      90.0
# BIM         Butwal       75.0
#             Lalitpur     78.0
# IT          Bhaktapur    92.0
#             Kathmandu    85.0
# Name: Marks, dtype: float64

# %%
#23. Find the average marks according to Department and City.
df.groupby(['Department', 'City'])['Marks'].mean()
# Out:
# Department  City
# BCA         Chitwan      88.0
#             Pokhara      90.0
# BIM         Butwal       75.0
#             Lalitpur     78.0
# IT          Bhaktapur    92.0
#             Kathmandu    85.0
# Name: Marks, dtype: float64

# %%
#24. Find the total marks according to Department and City.
df.groupby(['Department', 'City'])['Marks'].sum()
# Out:
# Department  City
# BCA         Chitwan      88
#             Pokhara      90
# BIM         Butwal       75
#             Lalitpur     78
# IT          Bhaktapur    92
#             Kathmandu    85
# Name: Marks, dtype: int64

# %%
#25. Find the highest marks according to Department and City.
df.groupby(['Department', 'City'])['Marks'].max()
# Out:
# Department  City
# BCA         Chitwan      88
#             Pokhara      90
# BIM         Butwal       75
#             Lalitpur     78
# IT          Bhaktapur    92
#             Kathmandu    85
# Name: Marks, dtype: int64

# %%
import pandas as pd

df1 = pd.DataFrame({
    'id': [1, 2, 3],
    'name': ['A', 'B', 'C']
})
df1
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df1

# %%
df2 = pd.DataFrame({
    'id': [1, 2, 4],
    'score': [85, 90, 88]
})

# %%
df2

# %%
result = pd.merge(df1, df2, on='id')
print(result)

# %%
pd.merge(df1, df2, on='id', how='inner')
#Keeps common rows only

# %%
# Test with new data
import pandas as pd

students = pd.DataFrame({
    'student_id': [101, 102, 103, 104],
    'student_name': ['Ram', 'Sita', 'Hari', 'Gita'],
    'department': ['CS', 'IT', 'CS', 'BCA']
})

print(students)

# %%
marks = pd.DataFrame({
    'student_id': [101, 102, 105],
    'marks': [88, 92, 75]
})

print(marks)

# %%
inner_join = pd.merge(students, marks, on='student_id', how='inner')
print(inner_join)
# Common records only

# %%
left_join = pd.merge(students, marks, on='student_id', how='left')
print(left_join)

# %%
right_join = pd.merge(students, marks, on='student_id', how='right')
print(right_join)

# %%
outer_join = pd.merge(students, marks, on='student_id', how='outer')
print(outer_join)
# Outer Join (Everything from both tables)

# %% [markdown]
# Easy Memory Trick
#
# Inner → common only
#
# Left → everything from first table
#
# Right → everything from second table
#
# Outer → everything from both
